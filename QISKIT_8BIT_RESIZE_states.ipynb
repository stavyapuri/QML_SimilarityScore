# %% [markdown]
# ### This model includes a Binary Quantum classification implementation using QISKIT ON AN 8-Qubit Circuit based on Transfer learning applied on another QISKIT Circuit invoking the QML MOdel Parameters for producing a Quantum State and then the calculation of its State Fidelity with another such implementation to produce a Similarity Score

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import qiskit
from IPython.display import clear_output
from qiskit import QuantumCircuit
from qiskit.algorithms.optimizers import COBYLA
from qiskit.circuit import ParameterVector, ClassicalRegister
from qiskit.circuit.library import ZFeatureMap
from qiskit.quantum_info import SparsePauliOp
from qiskit.utils import algorithm_globals
from qiskit_machine_learning.algorithms.classifiers import NeuralNetworkClassifier
from qiskit_machine_learning.neural_networks import EstimatorQNN
from sklearn.model_selection import train_test_split
from qiskit.quantum_info import Statevector
from qiskit import Aer, transpile, assemble
from qiskit.visualization import plot_histogram
from qiskit.quantum_info import state_fidelity
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import numpy as np
from PIL import Image

algorithm_globals.random_seed = 12345
# Out:
# /tmp/ipykernel_28102/1255559141.py:26: DeprecationWarning: The property ``qiskit.utils.algorithm_globals.QiskitAlgorithmGlobals.random_seed`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. This algorithm utility has been migrated to an independent package: https://github.com/qiskit-community/qiskit-algorithms. You can run ``pip install qiskit_algorithms`` and import ``from qiskit_algorithms.utils`` instead.
#   algorithm_globals.random_seed = 12345

# %%
# We now define a two qubit unitary as defined in [3]
def conv_circuit(params):
    target = QuantumCircuit(2)
    target.rz(-np.pi / 2, 1)
    target.cx(1, 0)
    target.rz(params[0], 0)
    target.ry(params[1], 1)
    target.cx(0, 1)
    target.ry(params[2], 1)
    target.cx(1, 0)
    target.rz(np.pi / 2, 0)
    return target


# Let's draw this circuit and see what it looks like
params = ParameterVector("θ", length=3)
circuit = conv_circuit(params)
# circuit.draw("mpl")

# %%
def conv_layer(num_qubits, param_prefix):
    qc = QuantumCircuit(num_qubits, name="Convolutional Layer")
    qubits = list(range(num_qubits))
    param_index = 0
    params = ParameterVector(param_prefix, length=num_qubits * 3)
    for q1, q2 in zip(qubits[0::2], qubits[1::2]):
        qc = qc.compose(conv_circuit(params[param_index : (param_index + 3)]), [q1, q2])
        qc.barrier()
        param_index += 3
    for q1, q2 in zip(qubits[1::2], qubits[2::2] + [0]):
        qc = qc.compose(conv_circuit(params[param_index : (param_index + 3)]), [q1, q2])
        qc.barrier()
        param_index += 3

    qc_inst = qc.to_instruction()

    qc = QuantumCircuit(num_qubits)
    qc.append(qc_inst, qubits)
    return qc


circuit = conv_layer(4, "θ")
# circuit.decompose().draw("mpl")

# %%
def pool_circuit(params):
    target = QuantumCircuit(2)
    target.rz(-np.pi / 2, 1)
    target.cx(1, 0)
    target.rz(params[0], 0)
    target.ry(params[1], 1)
    target.cx(0, 1)
    target.ry(params[2], 1)

    return target


params = ParameterVector("θ", length=3)
circuit = pool_circuit(params)
# circuit.draw("mpl")

# %%
def pool_layer(sources, sinks, param_prefix):
    num_qubits = len(sources) + len(sinks)
    qc = QuantumCircuit(num_qubits, name="Pooling Layer")
    param_index = 0
    params = ParameterVector(param_prefix, length=num_qubits // 2 * 3)
    for source, sink in zip(sources, sinks):
        qc = qc.compose(pool_circuit(params[param_index : (param_index + 3)]), [source, sink])
        qc.barrier()
        param_index += 3

    qc_inst = qc.to_instruction()

    qc = QuantumCircuit(num_qubits)
    qc.append(qc_inst, range(num_qubits))
    return qc


sources = [0, 1]
sinks = [2, 3]
circuit = pool_layer(sources, sinks, "θ")
# circuit.decompose().draw("mpl")

# %%
feature_map = ZFeatureMap(8)

ansatz = QuantumCircuit(8, name="Ansatz")

# First Convolutional Layer
ansatz.compose(conv_layer(8, "c1"), list(range(8)), inplace=True)

# First Pooling Layer
ansatz.compose(pool_layer([0, 1, 2, 3], [4, 5, 6, 7], "p1"), list(range(8)), inplace=True)

# Second Convolutional Layer
ansatz.compose(conv_layer(4, "c2"), list(range(4, 8)), inplace=True)

# Second Pooling Layer
ansatz.compose(pool_layer([0, 1], [2, 3], "p2"), list(range(4, 8)), inplace=True)

# Third Convolutional Layer
ansatz.compose(conv_layer(2, "c3"), list(range(6, 8)), inplace=True)

# Third Pooling Layer
ansatz.compose(pool_layer([0], [1], "p3"), list(range(6, 8)), inplace=True)

# Combining the feature map and ansatz
circuit = QuantumCircuit(8)
circuit.compose(feature_map, range(8), inplace=True)
circuit.compose(ansatz, range(8), inplace=True)

observable = SparsePauliOp.from_list([("Z" + "I" * 7, 1)])

# we decompose the circuit for the QNN to avoid additional data copying
qnn = EstimatorQNN(
    circuit=circuit.decompose(),
    observables=observable,
    input_params=feature_map.parameters,
    weight_params=ansatz.parameters,
)

# %%
# circuit.draw("mpl")

# %%
classifier = NeuralNetworkClassifier(
    qnn,
    optimizer=COBYLA(maxiter=200),  # Set max iterations here
)

# %%
def conv_layer_state(num_qubits, paramvector):
    qc = QuantumCircuit(num_qubits, name="Convolutional Layer")
    qubits = list(range(num_qubits))
    param_index = 0
    params = paramvector
    for q1, q2 in zip(qubits[0::2], qubits[1::2]):
        qc = qc.compose(conv_circuit(params[param_index : (param_index + 3)]), [q1, q2])
        qc.barrier()
        param_index += 3
    for q1, q2 in zip(qubits[1::2], qubits[2::2] + [0]):
        qc = qc.compose(conv_circuit(params[param_index : (param_index + 3)]), [q1, q2])
        qc.barrier()
        param_index += 3

    qc_inst = qc.to_instruction()

    qc = QuantumCircuit(num_qubits)
    qc.append(qc_inst, qubits)
    return qc

# %%
def pool_layer_state(sources, sinks, paramvector):
    num_qubits = len(sources) + len(sinks)
    qc = QuantumCircuit(num_qubits, name="Pooling Layer")
    param_index = 0
    params = paramvector
    for source, sink in zip(sources, sinks):
        qc = qc.compose(pool_circuit(params[param_index : (param_index + 3)]), [source, sink])
        qc.barrier()
        param_index += 3

    qc_inst = qc.to_instruction()

    qc = QuantumCircuit(num_qubits)
    qc.append(qc_inst, range(num_qubits))
    return qc

# %%
def data_image(label, class_dir):
    x = []
    y = []
    for image_file in range(6):
        image_path = os.path.join(class_dir, f"{image_file+1}.jpeg")
        # image_path = class_dir+'/'+ str(image_file+1)
        # Load and preprocess the image
        image = Image.open(image_path)
        image = image.convert('L')
        # plt.imshow(image)
        image = image.resize((28, 28))  # Resize to the model's input size
        image = np.array(image) / 255.0  # Normalize pixel values

        x.append(image)
        y.append(label)

    x = np.array(x)
    y = np.array(y)
    return x, y

# %%
def calculate_fidelity(rho, sigma):
    # Calculate the square root of rho
    sqrt_rho = np.sqrt(rho)
    
    # Calculate the matrix product: sqrt_rho * sigma
    term1 = np.matmul(sqrt_rho, np.matmul(sigma, sqrt_rho))
    
    # Calculate the square root of the result: sqrt(sqrt_rho * sigma * sqrt_rho)
    # print(term1)
    sqrt_result = np.sqrt(term1)
    
    # Calculate the trace of the square root: Tr(sqrt(sqrt_rho * sigma * sqrt_rho))
    trace_sqrt_result = np.trace(sqrt_result)
    
    # Calculate the fidelity: Tr(sqrt(sqrt_rho * sigma * sqrt_rho))^2
    fidelity = np.abs(trace_sqrt_result)**2
    
    return fidelity

# %%
n = 6
with open('fidelity_results_8BIT_RESIZE_states.txt', 'w') as file:
    for p in range(n):
        x = str(1+p)
        dataset_dir1 = '/home/stavya/Desktop/ML/Cosface/data/S'+x
        custom_x1, custom_y1 = data_image(1+p, dataset_dir1)
        custom_x1.resize(6,8)
        for q in range(n):
            y = str(1+q)
            if x!=y:
                dataset_dir2 = '/home/stavya/Desktop/ML/Cosface/data/S'+y
                custom_x2, custom_y2 = data_image(1+q, dataset_dir2)
                custom_x2.resize(6,8)
                custom_x = np.vstack((custom_x1, custom_x2))
                custom_y = np.append(custom_y1, custom_y2)
                print(custom_x.shape, custom_y.shape)
                
                classifier.fit(custom_x, custom_y)
                def extract_param(prefix, paramvector):
                    if prefix == "c1":
                        for i in range(24):
                            paramvector[i] = classifier.weights[i]
                    
                    if prefix == "p1":
                        for i in range(12):
                            paramvector[i] = classifier.weights[i+24]
                    
                    if prefix == "c2":
                        for i in range(12):
                            paramvector[i] = classifier.weights[i+36]
                    
                    if prefix == "p2":
                        for i in range(6):
                            paramvector[i] = classifier.weights[i+48]

                    if prefix == "c3":
                        for i in range(6):
                            paramvector[i] = classifier.weights[i+54]
                    
                    if prefix == "p3":
                        for i in range(3):
                            paramvector[i] = classifier.weights[i+60]

                    return (paramvector)
                
                paramvec1_c1 = np.zeros(24)
                c1_params1 = extract_param("c1", paramvec1_c1)
                paramvec1_p1 = np.zeros(12)
                p1_params1 = extract_param("p1", paramvec1_p1)
                paramvec1_c2 = np.zeros(12)
                c2_params1 = extract_param("c2", paramvec1_c2)
                paramvec1_p2 = np.zeros(6)
                p2_params1 = extract_param("p2", paramvec1_p2)
                paramvec1_c3 = np.zeros(6)
                c3_params1 = extract_param("c3", paramvec1_c3)
                paramvec1_p3 = np.zeros(3)
                p3_params1 = extract_param("p3", paramvec1_p3)

                c1_circuit = conv_layer_state(8, c1_params1)
                p1_circuit = pool_layer_state([0, 1, 2, 3], [4, 5, 6, 7], p1_params1)
                c2_circuit = conv_layer_state(4, c2_params1)
                p2_circuit = pool_layer_state([0, 1], [2, 3], p2_params1)
                c3_circuit = conv_layer_state(2, c3_params1)
                p3_circuit = pool_layer_state([0], [1], p3_params1)


                # final = np.zeros((59,60))
                for i in range(6):
                    data1 = custom_x1[i]
                    normalized_data1 = (np.array(data1) - np.min(data1)) / (np.max(data1) - np.min(data1))
                    angles1 = 2 * np.pi * normalized_data1
                    feature_map_state1 = ZFeatureMap(8)
                    feature_map_circuit1 = feature_map_state1.bind_parameters(dict(zip(feature_map_state1.parameters, angles1)))
                    ansatz_state1 = QuantumCircuit(8, name="Ansatz")
                    ansatz_state1.compose(c1_circuit, list(range(8)), inplace=True)
                    ansatz_state1.compose(p1_circuit, list(range(8)), inplace=True)
                    ansatz_state1.compose(c2_circuit, list(range(4,8)), inplace=True)
                    ansatz_state1.compose(p2_circuit, list(range(4, 8)), inplace=True)
                    ansatz_state1.compose(c3_circuit, list(range(6, 8)), inplace=True)
                    ansatz_state1.compose(p3_circuit, list(range(6, 8)), inplace=True)
                    full_circuit1 = QuantumCircuit(8)
                    full_circuit1.compose(feature_map_circuit1, range(8), inplace=True)
                    full_circuit1.compose(ansatz_state1, range(8), inplace=True)
                    c1 = ClassicalRegister(1, name='c')
                    full_circuit1.add_register(c1)
                    full_circuit1.measure(7, 0)
                    simulator1 = Aer.get_backend('statevector_simulator')
                    transpiled_circuit1 = transpile(full_circuit1, simulator1)
                    qobj1 = assemble(transpiled_circuit1)
                    result1 = simulator1.run(qobj1).result()
                    sv1 = result1.get_statevector()

                    for j in range(12):
                        # if i != j:
                        data2 = custom_x[j]
                        normalized_data2 = (np.array(data2) - np.min(data2)) / (np.max(data2) - np.min(data2))
                        angles2 = 2 * np.pi * normalized_data2
                        feature_map_state2 = ZFeatureMap(8)
                        feature_map_circuit2 = feature_map_state2.bind_parameters(dict(zip(feature_map_state2.parameters, angles2)))
                        ansatz_state2 = QuantumCircuit(8, name="Ansatz")
                        ansatz_state2.compose(c1_circuit, list(range(8)), inplace=True)
                        ansatz_state2.compose(p1_circuit, list(range(8)), inplace=True)
                        ansatz_state2.compose(c2_circuit, list(range(4,8)), inplace=True)
                        ansatz_state2.compose(p2_circuit, list(range(4, 8)), inplace=True)
                        ansatz_state2.compose(c3_circuit, list(range(6, 8)), inplace=True)
                        ansatz_state2.compose(p3_circuit, list(range(6, 8)), inplace=True)
                        full_circuit2 = QuantumCircuit(8)
                        full_circuit2.compose(feature_map_circuit2, range(8), inplace=True)
                        full_circuit2.compose(ansatz_state2, range(8), inplace=True)
                        c2 = ClassicalRegister(1, name='c')
                        full_circuit2.add_register(c2)
                        full_circuit2.measure(7, 0)
                        simulator2 = Aer.get_backend('statevector_simulator')
                        transpiled_circuit2 = transpile(full_circuit2, simulator2)
                        qobj2 = assemble(transpiled_circuit2)
                        result2 = simulator2.run(qobj2).result();
                        sv2 = result2.get_statevector()
                        
                        fidelity = state_fidelity(sv1, sv2)

                        if j >= 6:
                            file.write(f" {x}_{i+1}_{y}_{j-5} {fidelity}\n")
                        elif j < 6:
                            file.write(f" {x}_{i+1}_{x}_{j+1} {fidelity}\n")


                        # if j >= 6:
                        # # final[x-1+i][y-1+j] = state_fidelity(sv1, sv2)
                        #     print("\nState Fidelity between Student",x,'image',i+1, " and Student",y,'image',j-5, 'is', fidelity)

                        # elif j< 6:
                        #     print("\nState Fidelity between Student",x,'image',i+1, " and Student",x,'image',j+1, 'is', fidelity)
# Out:
# (12, 8) (12,)
# /tmp/ipykernel_28102/1856374619.py:72: DeprecationWarning: The method ``qiskit.circuit.quantumcircuit.QuantumCircuit.bind_parameters()`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. Use assign_parameters() instead
#   feature_map_circuit1 = feature_map_state1.bind_parameters(dict(zip(feature_map_state1.parameters, angles1)))
# /tmp/ipykernel_28102/1856374619.py:89: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   result1 = simulator1.run(qobj1).result()
# /tmp/ipykernel_28102/1856374619.py:98: DeprecationWarning: The method ``qiskit.circuit.quantumcircuit.QuantumCircuit.bind_parameters()`` is deprecated as of qiskit 0.45.0. It will be removed no earlier than 3 months after the release date. Use assign_parameters() instead
#   feature_map_circuit2 = feature_map_state2.bind_parameters(dict(zip(feature_map_state2.parameters, angles2)))
# /tmp/ipykernel_28102/1856374619.py:115: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   result2 = simulator2.run(qobj2).result();
# State Fidelity between Student 1 image 1  and Student 1 image 1 is 1.0000000000000009
#
# State Fidelity between Student 1 image 1  and Student 1 image 2 is 0.007959084391602889
#
# State Fidelity between Student 1 image 1  and Student 1 image 3 is 0.0
#
# State Fidelity between Student 1 image 1  and Student 1 image 4 is 0.0
#
# State Fidelity between Student 1 image 1  and Student 1 image 5 is 0.002613127838087413
#
# State Fidelity between Student 1 image 1  and Student 1 image 6 is 0.0
#
# State Fidelity between Student 1 image 1  and Student 2 image 1 is 0.0
#
# State Fidelity between Student 1 image 1  and Student 2 image 2 is 0.006067950476839123
#
# State Fidelity between Student 1 image 1  and Student 2 image 3 is 0.0
#
# State Fidelity between Student 1 image 1  and Student 2 image 4 is 0.0
#
# State Fidelity between Student 1 image 1  and Student 2 image 5 is 0.3033835886493319
#
# State Fidelity between Student 1 image 1  and Student 2 image 6 is 0.058662196520153975
#
# State Fidelity between Student 1 image 2  and Student 1 image 1 is 0.0
#
# State Fidelity between Student 1 image 2  and Student 1 image 2 is 0.9999999999999998
#
# State Fidelity between Student 1 image 2  and Student 1 image 3 is 0.0
#
# State Fidelity between Student 1 image 2  and Student 1 image 4 is 0.0
#
# State Fidelity between Student 1 image 2  and Student 1 image 5 is 0.0
#
# State Fidelity between Student 1 image 2  and Student 1 image 6 is 0.033780349615005326
#
# State Fidelity between Student 1 image 2  and Student 2 image 1 is 0.0
#
# State Fidelity between Student 1 image 2  and Student 2 image 2 is 0.01860655122136456
#
# State Fidelity between Student 1 image 2  and Student 2 image 3 is 0.023121792394561202
#
# State Fidelity between Student 1 image 2  and Student 2 image 4 is 0.0
#
# State Fidelity between Student 1 image 2  and Student 2 image 5 is 0.003132853004851172
#
# State Fidelity between Student 1 image 2  and Student 2 image 6 is 0.01964867802737183
#
# State Fidelity between Student 1 image 3  and Student 1 image 1 is 0.04948711976068092
#
# State Fidelity between Student 1 image 3  and Student 1 image 2 is 0.0
#
# State Fidelity between Student 1 image 3  and Student 1 image 3 is 1.0
#
# State Fidelity between Student 1 image 3  and Student 1 image 4 is 0.0
#
# State Fidelity between Student 1 image 3  and Student 1 image 5 is 0.0
#
# State Fidelity between Student 1 image 3  and Student 1 image 6 is 0.0
#
# State Fidelity between Student 1 image 3  and Student 2 image 1 is 0.0
#
# State Fidelity between Student 1 image 3  and Student 2 image 2 is 0.0012385746858885594
#
# State Fidelity between Student 1 image 3  and Student 2 image 3 is 0.0031751983007390454
#
# State Fidelity between Student 1 image 3  and Student 2 image 4 is 0.002161582877905099
#
# State Fidelity between Student 1 image 3  and Student 2 image 5 is 0.0
#
# State Fidelity between Student 1 image 3  and Student 2 image 6 is 0.0
#
# State Fidelity between Student 1 image 4  and Student 1 image 1 is 0.0
#
# State Fidelity between Student 1 image 4  and Student 1 image 2 is 0.0004435888832990872
#
# State Fidelity between Student 1 image 4  and Student 1 image 3 is 4.913002577036921e-05
#
# State Fidelity between Student 1 image 4  and Student 1 image 4 is 1.0000000000000013
#
# State Fidelity between Student 1 image 4  and Student 1 image 5 is 0.006315139296862532
#
# State Fidelity between Student 1 image 4  and Student 1 image 6 is 0.0
#
# State Fidelity between Student 1 image 4  and Student 2 image 1 is 0.0
#
# State Fidelity between Student 1 image 4  and Student 2 image 2 is 0.007729703832043721
#
# State Fidelity between Student 1 image 4  and Student 2 image 3 is 0.0
#
# State Fidelity between Student 1 image 4  and Student 2 image 4 is 0.0008110477837145303
#
# State Fidelity between Student 1 image 4  and Student 2 image 5 is 0.0
#
# State Fidelity between Student 1 image 4  and Student 2 image 6 is 0.011178508742164755
#
# State Fidelity between Student 1 image 5  and Student 1 image 1 is 0.002613127838087413
#
# State Fidelity between Student 1 image 5  and Student 1 image 2 is 0.0007481672140610855
#
# State Fidelity between Student 1 image 5  and Student 1 image 3 is 0.013825873143127906
#
# State Fidelity between Student 1 image 5  and Student 1 image 4 is 0.0
#
# State Fidelity between Student 1 image 5  and Student 1 image 5 is 0.9999999999999996
#
# State Fidelity between Student 1 image 5  and Student 1 image 6 is 0.0009950392633570027
#
# State Fidelity between Student 1 image 5  and Student 2 image 1 is 0.0
#
# State Fidelity between Student 1 image 5  and Student 2 image 2 is 0.0
#
# State Fidelity between Student 1 image 5  and Student 2 image 3 is 0.0
#
# State Fidelity between Student 1 image 5  and Student 2 image 4 is 0.0
#
# State Fidelity between Student 1 image 5  and Student 2 image 5 is 0.0
#
# State Fidelity between Student 1 image 5  and Student 2 image 6 is 0.0019087214816031733
#
# State Fidelity between Student 1 image 6  and Student 1 image 1 is 0.003758653190989082
#
# State Fidelity between Student 1 image 6  and Student 1 image 2 is 0.033780349615005326
#
# State Fidelity between Student 1 image 6  and Student 1 image 3 is 0.0
#
# State Fidelity between Student 1 image 6  and Student 1 image 4 is 0.0026416298271468995
#
# State Fidelity between Student 1 image 6  and Student 1 image 5 is 0.0
#
# State Fidelity between Student 1 image 6  and Student 1 image 6 is 0.0
#
# State Fidelity between Student 1 image 6  and Student 2 image 1 is 0.0
#
# State Fidelity between Student 1 image 6  and Student 2 image 2 is 0.0
#
# State Fidelity between Student 1 image 6  and Student 2 image 3 is 0.0048507016300836266
#
# State Fidelity between Student 1 image 6  and Student 2 image 4 is 0.029558641257276745
#
# State Fidelity between Student 1 image 6  and Student 2 image 5 is 0.0
#
# State Fidelity between Student 1 image 6  and Student 2 image 6 is 0.007055836135648613
# (12, 8) (12,)
#
# State Fidelity between Student 1 image 1  and Student 1 image 1 is 0.9999999999999991
#
# State Fidelity between Student 1 image 1  and Student 1 image 2 is 3.6270273661117764e-05
#
# State Fidelity between Student 1 image 1  and Student 1 image 3 is 0.016618514951766514
#
# State Fidelity between Student 1 image 1  and Student 1 image 4 is 0.0
#
# State Fidelity between Student 1 image 1  and Student 1 image 5 is 0.0
#
# State Fidelity between Student 1 image 1  and Student 1 image 6 is 0.01618119405783253
#
# State Fidelity between Student 1 image 1  and Student 3 image 1 is 0.0
#
# State Fidelity between Student 1 image 1  and Student 3 image 2 is 0.0
#
# State Fidelity between Student 1 image 1  and Student 3 image 3 is 0.0
#
# State Fidelity between Student 1 image 1  and Student 3 image 4 is 0.0007691849772494828
#
# State Fidelity between Student 1 image 1  and Student 3 image 5 is 0.0
#
# State Fidelity between Student 1 image 1  and Student 3 image 6 is 0.0
#
# State Fidelity between Student 1 image 2  and Student 1 image 1 is 0.0
#
# State Fidelity between Student 1 image 2  and Student 1 image 2 is 0.0
#
# State Fidelity between Student 1 image 2  and Student 1 image 3 is 2.8151855240281513e-05
#
# State Fidelity between Student 1 image 2  and Student 1 image 4 is 0.0
#
# State Fidelity between Student 1 image 2  and Student 1 image 5 is 0.0022461290946805532
#
# State Fidelity between Student 1 image 2  and Student 1 image 6 is 0.07711576883970735
#
# State Fidelity between Student 1 image 2  and Student 3 image 1 is 0.002785629273670388
#
# State Fidelity between Student 1 image 2  and Student 3 image 2 is 0.006910228316041465
#
# State Fidelity between Student 1 image 2  and Student 3 image 3 is 0.035815933785515744
#
# State Fidelity between Student 1 image 2  and Student 3 image 4 is 0.001263495823452637
#
# State Fidelity between Student 1 image 2  and Student 3 image 5 is 0.0
#
# State Fidelity between Student 1 image 2  and Student 3 image 6 is 0.0031728014760917054
#
# State Fidelity between Student 1 image 3  and Student 1 image 1 is 0.0
#
# State Fidelity between Student 1 image 3  and Student 1 image 2 is 2.8611758823816345e-05
#
# State Fidelity between Student 1 image 3  and Student 1 image 3 is 0.9999999999999996
#
# State Fidelity between Student 1 image 3  and Student 1 image 4 is 0.0
#
# State Fidelity between Student 1 image 3  and Student 1 image 5 is 0.0
#
# State Fidelity between Student 1 image 3  and Student 1 image 6 is 0.006055058460690885
#
# State Fidelity between Student 1 image 3  and Student 3 image 1 is 0.0
#
# State Fidelity between Student 1 image 3  and Student 3 image 2 is 0.0
#
# State Fidelity between Student 1 image 3  and Student 3 image 3 is 0.0
#
# State Fidelity between Student 1 image 3  and Student 3 image 4 is 0.0
#
# State Fidelity between Student 1 image 3  and Student 3 image 5 is 0.01810698949495659
#
# State Fidelity between Student 1 image 3  and Student 3 image 6 is 0.0
#
# State Fidelity between Student 1 image 4  and Student 1 image 1 is 0.0
#
# State Fidelity between Student 1 image 4  and Student 1 image 2 is 0.00011727966905327284
#
# State Fidelity between Student 1 image 4  and Student 1 image 3 is 0.0
#
# State Fidelity between Student 1 image 4  and Student 1 image 4 is 1.0000000000000018
#
# State Fidelity between Student 1 image 4  and Student 1 image 5 is 0.0
#
# State Fidelity between Student 1 image 4  and Student 1 image 6 is 0.0
#
# State Fidelity between Student 1 image 4  and Student 3 image 1 is 0.004307886224400546
#
# State Fidelity between Student 1 image 4  and Student 3 image 2 is 0.011280942328284672
#
# State Fidelity between Student 1 image 4  and Student 3 image 3 is 0.0013865451304297094
#
# State Fidelity between Student 1 image 4  and Student 3 image 4 is 0.0
#
# State Fidelity between Student 1 image 4  and Student 3 image 5 is 0.0022818187250168345
#
# State Fidelity between Student 1 image 4  and Student 3 image 6 is 0.0
#
# State Fidelity between Student 1 image 5  and Student 1 image 1 is 0.0
#
# State Fidelity between Student 1 image 5  and Student 1 image 2 is 0.0032993464468251605
#
# State Fidelity between Student 1 image 5  and Student 1 image 3 is 0.0
#
# State Fidelity between Student 1 image 5  and Student 1 image 4 is 0.0
#
# State Fidelity between Student 1 image 5  and Student 1 image 5 is 0.9999999999999993
#
# State Fidelity between Student 1 image 5  and Student 1 image 6 is 0.0
#
# State Fidelity between Student 1 image 5  and Student 3 image 1 is 0.0
#
# State Fidelity between Student 1 image 5  and Student 3 image 2 is 0.0
#
# State Fidelity between Student 1 image 5  and Student 3 image 3 is 0.0
#
# State Fidelity between Student 1 image 5  and Student 3 image 4 is 0.008049253358800867
#
# State Fidelity between Student 1 image 5  and Student 3 image 5 is 0.0
#
# State Fidelity between Student 1 image 5  and Student 3 image 6 is 7.10022302171438e-05
#
# State Fidelity between Student 1 image 6  and Student 1 image 1 is 0.0011916848386163946
#
# State Fidelity between Student 1 image 6  and Student 1 image 2 is 0.0
#
# State Fidelity between Student 1 image 6  and Student 1 image 3 is 0.00720100565097174
#
# State Fidelity between Student 1 image 6  and Student 1 image 4 is 0.0
#
# State Fidelity between Student 1 image 6  and Student 1 image 5 is 0.0
#
# State Fidelity between Student 1 image 6  and Student 1 image 6 is 1.0000000000000009
#
# State Fidelity between Student 1 image 6  and Student 3 image 1 is 0.0
#
# State Fidelity between Student 1 image 6  and Student 3 image 2 is 0.0018985129032493343
#
# State Fidelity between Student 1 image 6  and Student 3 image 3 is 0.011290175762569856
#
# State Fidelity between Student 1 image 6  and Student 3 image 4 is 0.0
#
# State Fidelity between Student 1 image 6  and Student 3 image 5 is 0.0007570922238687569
#
# State Fidelity between Student 1 image 6  and Student 3 image 6 is 0.0
# (12, 8) (12,)
#
# State Fidelity between Student 2 image 1  and Student 2 image 1 is 1.0
#
# State Fidelity between Student 2 image 1  and Student 2 image 2 is 0.0
#
# State Fidelity between Student 2 image 1  and Student 2 image 3 is 0.0
#
# State Fidelity between Student 2 image 1  and Student 2 image 4 is 0.02252531389823318
#
# State Fidelity between Student 2 image 1  and Student 2 image 5 is 0.015168964914893248
#
# State Fidelity between Student 2 image 1  and Student 2 image 6 is 0.0
#
# State Fidelity between Student 2 image 1  and Student 1 image 1 is 0.004605862639989718
#
# State Fidelity between Student 2 image 1  and Student 1 image 2 is 0.0
#
# State Fidelity between Student 2 image 1  and Student 1 image 3 is 0.0
#
# State Fidelity between Student 2 image 1  and Student 1 image 4 is 0.0034674951811591984
#
# State Fidelity between Student 2 image 1  and Student 1 image 5 is 0.0
#
# State Fidelity between Student 2 image 1  and Student 1 image 6 is 0.00040192472244665
#
# State Fidelity between Student 2 image 2  and Student 2 image 1 is 0.0
#
# State Fidelity between Student 2 image 2  and Student 2 image 2 is 0.9999999999999998
#
# State Fidelity between Student 2 image 2  and Student 2 image 3 is 0.004741138727108982
#
# State Fidelity between Student 2 image 2  and Student 2 image 4 is 0.0010330837743897188
#
# State Fidelity between Student 2 image 2  and Student 2 image 5 is 0.0
#
# State Fidelity between Student 2 image 2  and Student 2 image 6 is 0.0044244873583550405
#
# State Fidelity between Student 2 image 2  and Student 1 image 1 is 0.004468977641616541
#
# State Fidelity between Student 2 image 2  and Student 1 image 2 is 0.0
#
# State Fidelity between Student 2 image 2  and Student 1 image 3 is 0.008084513552168337
#
# State Fidelity between Student 2 image 2  and Student 1 image 4 is 0.003952746739305942
#
# State Fidelity between Student 2 image 2  and Student 1 image 5 is 0.006216895351234229
#
# State Fidelity between Student 2 image 2  and Student 1 image 6 is 0.0
#
# State Fidelity between Student 2 image 3  and Student 2 image 1 is 0.0
#
# State Fidelity between Student 2 image 3  and Student 2 image 2 is 0.0
#
# State Fidelity between Student 2 image 3  and Student 2 image 3 is 0.9999999999999996
#
# State Fidelity between Student 2 image 3  and Student 2 image 4 is 0.00846625708516602
#
# State Fidelity between Student 2 image 3  and Student 2 image 5 is 0.0
#
# State Fidelity between Student 2 image 3  and Student 2 image 6 is 0.0
#
# State Fidelity between Student 2 image 3  and Student 1 image 1 is 0.0
#
# State Fidelity between Student 2 image 3  and Student 1 image 2 is 0.0
#
# State Fidelity between Student 2 image 3  and Student 1 image 3 is 0.005485043304881881
#
# State Fidelity between Student 2 image 3  and Student 1 image 4 is 0.0
#
# State Fidelity between Student 2 image 3  and Student 1 image 5 is 0.0
#
# State Fidelity between Student 2 image 3  and Student 1 image 6 is 0.0
#
# State Fidelity between Student 2 image 4  and Student 2 image 1 is 0.0
#
# State Fidelity between Student 2 image 4  and Student 2 image 2 is 0.0010330837743897188
#
# State Fidelity between Student 2 image 4  and Student 2 image 3 is 0.00846625708516602
#
# State Fidelity between Student 2 image 4  and Student 2 image 4 is 0.9999999999999987
#
# State Fidelity between Student 2 image 4  and Student 2 image 5 is 0.0
#
# State Fidelity between Student 2 image 4  and Student 2 image 6 is 0.00949455649354784
#
# State Fidelity between Student 2 image 4  and Student 1 image 1 is 0.3553490951988476
#
# State Fidelity between Student 2 image 4  and Student 1 image 2 is 0.012713104276863216
#
# State Fidelity between Student 2 image 4  and Student 1 image 3 is 0.004430808434485339
#
# State Fidelity between Student 2 image 4  and Student 1 image 4 is 0.011166352138495017
#
# State Fidelity between Student 2 image 4  and Student 1 image 5 is 0.0
#
# State Fidelity between Student 2 image 4  and Student 1 image 6 is 0.0
#
# State Fidelity between Student 2 image 5  and Student 2 image 1 is 0.014695478339794872
#
# State Fidelity between Student 2 image 5  and Student 2 image 2 is 0.0
#
# State Fidelity between Student 2 image 5  and Student 2 image 3 is 0.0
#
# State Fidelity between Student 2 image 5  and Student 2 image 4 is 0.08008288307215293
#
# State Fidelity between Student 2 image 5  and Student 2 image 5 is 0.0
#
# State Fidelity between Student 2 image 5  and Student 2 image 6 is 0.0
#
# State Fidelity between Student 2 image 5  and Student 1 image 1 is 0.0
#
# State Fidelity between Student 2 image 5  and Student 1 image 2 is 0.0
#
# State Fidelity between Student 2 image 5  and Student 1 image 3 is 0.0
#
# State Fidelity between Student 2 image 5  and Student 1 image 4 is 0.0
#
# State Fidelity between Student 2 image 5  and Student 1 image 5 is 0.009376184583695052
#
# State Fidelity between Student 2 image 5  and Student 1 image 6 is 0.006007400433357738
#
# State Fidelity between Student 2 image 6  and Student 2 image 1 is 0.016707030730114644
#
# State Fidelity between Student 2 image 6  and Student 2 image 2 is 0.0
#
# State Fidelity between Student 2 image 6  and Student 2 image 3 is 0.1977441897971733
#
# State Fidelity between Student 2 image 6  and Student 2 image 4 is 0.0
#
# State Fidelity between Student 2 image 6  and Student 2 image 5 is 0.020663217125147623
#
# State Fidelity between Student 2 image 6  and Student 2 image 6 is 0.9999999999999993
#
# State Fidelity between Student 2 image 6  and Student 1 image 1 is 0.085504347304411
#
# State Fidelity between Student 2 image 6  and Student 1 image 2 is 0.0
#
# State Fidelity between Student 2 image 6  and Student 1 image 3 is 0.0
#
# State Fidelity between Student 2 image 6  and Student 1 image 4 is 0.0
#
# State Fidelity between Student 2 image 6  and Student 1 image 5 is 0.0031909421608769368
#
# State Fidelity between Student 2 image 6  and Student 1 image 6 is 0.0054617988795630954
# (12, 8) (12,)
# capi_return is NULL
# Call-back cb_calcfc_in__cobyla__user__routines failed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 17
#      14 custom_y = np.append(custom_y1, custom_y2)
#      15 print(custom_x.shape, custom_y.shape)
# ---> 17 classifier.fit(custom_x, custom_y)
#      18 def extract_param(prefix, paramvector):
#      19     if prefix == "c1":
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/qiskit_machine_learning/algorithms/trainable_model.py:199, in TrainableModel.fit(self, X, y)
#     196 if not self._warm_start:
#     197     self._fit_result = None
# --> 199 self._fit_result = self._fit_internal(X, y)
#     200 return self
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/qiskit_machine_learning/algorithms/classifiers/neural_network_classifier.py:115, in NeuralNetworkClassifier._fit_internal(self, X, y)
#     112 X, y = self._validate_input(X, y)
#     114 function = self._create_objective(X, y)
# --> 115 return self._minimize(function)
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/qiskit_machine_learning/algorithms/trainable_model.py:295, in TrainableModel._minimize(self, function)
#     291     optimizer_result = self._optimizer(
#     292         fun=objective, x0=initial_point, jac=function.gradient
#     293     )
#     294 else:
# --> 295     optimizer_result = self._optimizer.minimize(
#     296         fun=objective,
#     297         x0=initial_point,
#     298         jac=function.gradient,
#     299     )
#     300 return optimizer_result
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/qiskit/algorithms/optimizers/scipy_optimizer.py:154, in SciPyOptimizer.minimize(self, fun, x0, jac, bounds)
#     151     swapped_deprecated_args = True
#     152     self._options["maxfun"] = self._options.pop("maxiter")
# --> 154 raw_result = minimize(
#     155     fun=fun,
#     156     x0=x0,
#     157     method=self._method,
#     158     jac=jac,
#     159     bounds=bounds,
#     160     options=self._options,
#     161     **self._kwargs,
#     162 )
#     163 if swapped_deprecated_args:
#     164     self._options["maxiter"] = self._options.pop("maxfun")
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/scipy/optimize/_minimize.py:716, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     713     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     714                         **options)
#     715 elif meth == 'cobyla':
# --> 716     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     717                            bounds=bounds, **options)
#     718 elif meth == 'slsqp':
#     719     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     720                           constraints, callback=callback, **options)
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/scipy/optimize/_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/scipy/optimize/_cobyla_py.py:293, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     290         callback(np.copy(x))
#     292 info = np.zeros(4, np.float64)
# --> 293 xopt, info = cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     294                               rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     295                               dinfo=info, callback=wrapped_callback)
#     297 if info[3] > catol:
#     298     # Check constraint violation
#     299     info[0] = 4
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/scipy/optimize/_cobyla_py.py:281, in _minimize_cobyla.<locals>.calcfc(x, con)
#     280 def calcfc(x, con):
# --> 281     f = sf.fun(x)
#     282     i = 0
#     283     for size, c in izip(cons_lengths, constraints):
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:267, in ScalarFunction.fun(self, x)
#     265 if not np.array_equal(x, self.x):
#     266     self._update_x_impl(x)
# --> 267 self._update_fun()
#     268 return self.f
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/qiskit_machine_learning/algorithms/objective_functions.py:115, in BinaryObjectiveFunction.objective(self, weights)
#     113 def objective(self, weights: np.ndarray) -> float:
#     114     # predict is of shape (N, 1), where N is a number of samples
# --> 115     predict = self._neural_network_forward(weights)
#     116     target = np.array(self._y).reshape(predict.shape)
#     117     # float(...) is for mypy compliance
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/qiskit_machine_learning/algorithms/objective_functions.py:102, in ObjectiveFunction._neural_network_forward(self, weights)
#      97 # if we get the same weights, we don't compute the forward pass again.
#      98 if self._last_forward_weights is None or (
#      99     not np.all(np.isclose(weights, self._last_forward_weights))
#     100 ):
#     101     # compute forward and cache the results for re-use in backward
# --> 102     self._last_forward = self._neural_network.forward(self._X, weights)
#     103     # a copy avoids keeping a reference to the same array, so we are sure we have
#     104     # different arrays on the next iteration.
#     105     self._last_forward_weights = np.copy(weights)
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/qiskit_machine_learning/neural_networks/neural_network.py:226, in NeuralNetwork.forward(self, input_data, weights)
#     224 input_, shape = self._validate_input(input_data)
#     225 weights_ = self._validate_weights(weights)
# --> 226 output_data = self._forward(input_, weights_)
#     227 return self._validate_forward_output(output_data, shape)
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/qiskit_machine_learning/neural_networks/estimator_qnn.py:189, in EstimatorQNN._forward(self, input_data, weights)
#     183 job = self.estimator.run(
#     184     [self._circuit] * num_samples * self.output_shape[0],
#     185     [op for op in self._observables for _ in range(num_samples)],
#     186     np.tile(parameter_values_, (self.output_shape[0], 1)),
#     187 )
#     188 try:
# --> 189     results = job.result()
#     190 except Exception as exc:
#     191     raise QiskitMachineLearningError("Estimator job failed.") from exc
#
# File ~/anaconda3/envs/qtf/lib/python3.9/site-packages/qiskit/primitives/primitive_job.py:55, in PrimitiveJob.result(self)
#      53 """Return the results of the job."""
#      54 self._check_submitted()
# ---> 55 return self._future.result()
#
# File ~/anaconda3/envs/qtf/lib/python3.9/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~/anaconda3/envs/qtf/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:
